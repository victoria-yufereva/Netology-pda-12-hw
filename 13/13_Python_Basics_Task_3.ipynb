# %% [markdown]
# ### Задание 3
#
# В задаче сквозной аналитики вам предоставили данные по местоположению пользователей. Т. е. для каждого user_id известна последовательность координат (широта/долгота), когда они требовались приложению для полноценной работы. Как бы вы добавили эти сведения в таблицу визитов и покупок? Для составления ответа можно использовать вопросы:
# - У каждого пользователя известен набор координат. А для связывания с визитом или фактом покупки скорее всего потребуется одно-два числа. Как их получить?
# - Наборы координат одного и того же пользователя могут быть значительно удалены друг от друга. Как это отразится на вопросе расчетах пункта 1?
# - Какие дополнительные признаки можно получить из координат? Ведь это просто числа, которые сами по себе мало что дают.

# %% [markdown]
# Мы имеем:
# 1. датафрейм с id пользователей и их местоположениями (предполагается, что никаких данных о времени предоставления этой информации у нас нет)
# 2. датафрейм с id пользователей и их визиты и покупки
# Для работы с информацией по координатам мы можем придумать какой-нибудь общий для всех местоположений коэффициент (показатель) и формулу его вычисления. Например коэффиециент удаленности (и направления) пользователя от центра Москвы. Если пользователь использовал приложение в разных местах и эти координаты значительно удалены, коэффициентом становится среднее значение отдельных коэффиециентов местоположений. Также мы можем в отдельном столбце указывать количество уникальных мест использования приложения, а по умолчанию в значении будет стоять 1 (т.е. одно место). Тогда будет ясно, на основании какого количества местоположений был составлен показатель.
#
# Помимо всего вышеперечисленного, из первого датафрейма мы можем понять, где географически пользователю приходила мысль воспользоваться приложением, возможно он находился в тороговом/развлекательном центре, в каком-то определенном учреждении или в спальном районе города и т.д.
# Востребованность товара или услуги в конкретном регионе, сбор статистика запросов.
# Мы можем также косвенно оценить, насколько мобилен пользователь, эти данные также могут указывать на возраст пользователя, национальность (гражданство).
